# %%
pip install notebook jupyterlab nbclient nbconvert nbformat ipywidgets
# Out:
# Requirement already satisfied: notebook in c:\users\user\.conda\envs\python_course\lib\site-packages (7.2.2)
# Requirement already satisfied: jupyterlab in c:\users\user\.conda\envs\python_course\lib\site-packages (4.2.5)
# Requirement already satisfied: nbclient in c:\users\user\.conda\envs\python_course\lib\site-packages (0.10.0)
# Requirement already satisfied: nbconvert in c:\users\user\.conda\envs\python_course\lib\site-packages (7.16.4)
# Requirement already satisfied: nbformat in c:\users\user\.conda\envs\python_course\lib\site-packages (5.10.4)
# Requirement already satisfied: ipywidgets in c:\users\user\.conda\envs\python_course\lib\site-packages (8.1.5)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\user\.conda\envs\python_course\lib\site-packages (from notebook) (2.14.2)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in c:\users\user\.conda\envs\python_course\lib\site-packages (from notebook) (2.27.3)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in c:\users\user\.conda\envs\python_course\lib\site-packages (from notebook) (0.2.4)
# Requirement already satisfied: tornado>=6.2.0 in c:\users\user\.conda\envs\python_course\lib\site-packages (from notebook) (6.2)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\user\.conda\envs\python_course\lib\site-packages (from jupyterlab) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in c:\users\user\.conda\envs\python_course\lib\site-packages (from jupyterlab) (0.27.2)
# Requirement already satisfied: ipykernel>=6.5.0 in c:\users\user\.conda\envs\python_course\lib\site-packages (from jupyterlab) (6.29.5)
# Requirement already satisfied: jinja2>=3.0.3 in c:\users\user\.conda\envs\python_course\lib\site-packages (from jupyterlab) (3.1.4)
# Requirement already satisfied: jupyter-core in c:\users\user\.conda\envs\python_course\lib\site-packages (from jupyterlab) (5.7.2)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\user\.conda\envs\python_course\lib\site-packages (from jupyterlab) (2.2.5)
# Requirement already satisfied: packaging in c:\users\user\.conda\envs\python_course\lib\site-packages (from jupyterlab) (24.1)
# Requirement already satisfied: setuptools>=40.1.0 in c:\users\user\.conda\envs\python_course\lib\site-packages (from jupyterlab) (72.1.0)
# Requirement already satisfied: traitlets in c:\users\user\.conda\envs\python_course\lib\site-packages (from jupyterlab) (5.14.3)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\user\.conda\envs\python_course\lib\site-packages (from nbclient) (8.6.2)
# Requirement already satisfied: beautifulsoup4 in c:\users\user\.conda\envs\python_course\lib\site-packages (from nbconvert) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\user\.conda\envs\python_course\lib\site-packages (from nbconvert) (6.1.0)
# Requirement already satisfied: defusedxml in c:\users\user\.conda\envs\python_course\lib\site-packages (from nbconvert) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\user\.conda\envs\python_course\lib\site-packages (from nbconvert) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in c:\users\user\.conda\envs\python_course\lib\site-packages (from nbconvert) (3.0.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\user\.conda\envs\python_course\lib\site-packages (from nbconvert) (3.0.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\user\.conda\envs\python_course\lib\site-packages (from nbconvert) (1.5.1)
# Requirement already satisfied: pygments>=2.4.1 in c:\users\user\.conda\envs\python_course\lib\site-packages (from nbconvert) (2.18.0)
# Requirement already satisfied: tinycss2 in c:\users\user\.conda\envs\python_course\lib\site-packages (from nbconvert) (1.3.0)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\user\.conda\envs\python_course\lib\site-packages (from nbformat) (2.20.0)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\user\.conda\envs\python_course\lib\site-packages (from nbformat) (4.23.0)
# Requirement already satisfied: comm>=0.1.3 in c:\users\user\.conda\envs\python_course\lib\site-packages (from ipywidgets) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\user\.conda\envs\python_course\lib\site-packages (from ipywidgets) (8.27.0)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in c:\users\user\.conda\envs\python_course\lib\site-packages (from ipywidgets) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in c:\users\user\.conda\envs\python_course\lib\site-packages (from ipywidgets) (3.0.13)
# Requirement already satisfied: six>=1.9.0 in c:\users\user\.conda\envs\python_course\lib\site-packages (from bleach!=5.0.0->nbconvert) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\user\.conda\envs\python_course\lib\site-packages (from bleach!=5.0.0->nbconvert) (0.5.1)
# Requirement already satisfied: anyio in c:\users\user\.conda\envs\python_course\lib\site-packages (from httpx>=0.25.0->jupyterlab) (4.6.2.post1)
# Requirement already satisfied: certifi in c:\users\user\.conda\envs\python_course\lib\site-packages (from httpx>=0.25.0->jupyterlab) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\users\user\.conda\envs\python_course\lib\site-packages (from httpx>=0.25.0->jupyterlab) (1.0.6)
# Requirement already satisfied: idna in c:\users\user\.conda\envs\python_course\lib\site-packages (from httpx>=0.25.0->jupyterlab) (3.8)
# Requirement already satisfied: sniffio in c:\users\user\.conda\envs\python_course\lib\site-packages (from httpx>=0.25.0->jupyterlab) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\user\.conda\envs\python_course\lib\site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab) (0.14.0)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\user\.conda\envs\python_course\lib\site-packages (from ipykernel>=6.5.0->jupyterlab) (1.6.7)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\user\.conda\envs\python_course\lib\site-packages (from ipykernel>=6.5.0->jupyterlab) (0.1.7)
# Requirement already satisfied: nest-asyncio in c:\users\user\.conda\envs\python_course\lib\site-packages (from ipykernel>=6.5.0->jupyterlab) (1.6.0)
# Requirement already satisfied: psutil in c:\users\user\.conda\envs\python_course\lib\site-packages (from ipykernel>=6.5.0->jupyterlab) (5.9.0)
# Requirement already satisfied: pyzmq>=24 in c:\users\user\.conda\envs\python_course\lib\site-packages (from ipykernel>=6.5.0->jupyterlab) (24.0.1)
# Requirement already satisfied: decorator in c:\users\user\.conda\envs\python_course\lib\site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\user\.conda\envs\python_course\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.19.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\user\.conda\envs\python_course\lib\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.47)
# Requirement already satisfied: stack-data in c:\users\user\.conda\envs\python_course\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.6.2)
# Requirement already satisfied: typing-extensions>=4.6 in c:\users\user\.conda\envs\python_course\lib\site-packages (from ipython>=6.1.0->ipywidgets) (4.12.2)
# Requirement already satisfied: colorama in c:\users\user\.conda\envs\python_course\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.4.6)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\user\.conda\envs\python_course\lib\site-packages (from jsonschema>=2.6->nbformat) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\user\.conda\envs\python_course\lib\site-packages (from jsonschema>=2.6->nbformat) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\user\.conda\envs\python_course\lib\site-packages (from jsonschema>=2.6->nbformat) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\user\.conda\envs\python_course\lib\site-packages (from jsonschema>=2.6->nbformat) (0.20.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\user\.conda\envs\python_course\lib\site-packages (from jupyter-client>=6.1.12->nbclient) (2.9.0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\user\.conda\envs\python_course\lib\site-packages (from jupyter-core->jupyterlab) (4.2.2)
# Requirement already satisfied: pywin32>=300 in c:\users\user\.conda\envs\python_course\lib\site-packages (from jupyter-core->jupyterlab) (305.1)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\user\.conda\envs\python_course\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (23.1.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in c:\users\user\.conda\envs\python_course\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\user\.conda\envs\python_course\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.5.3)
# Requirement already satisfied: overrides>=5.0 in c:\users\user\.conda\envs\python_course\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\user\.conda\envs\python_course\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.21.0)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\user\.conda\envs\python_course\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (2.0.14)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\user\.conda\envs\python_course\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\user\.conda\envs\python_course\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\user\.conda\envs\python_course\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (1.8.0)
# Requirement already satisfied: babel>=2.10 in c:\users\user\.conda\envs\python_course\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook) (2.16.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\user\.conda\envs\python_course\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook) (0.9.25)
# Requirement already satisfied: requests>=2.31 in c:\users\user\.conda\envs\python_course\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook) (2.32.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\user\.conda\envs\python_course\lib\site-packages (from beautifulsoup4->nbconvert) (2.6)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\user\.conda\envs\python_course\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook) (21.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\user\.conda\envs\python_course\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.4)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\user\.conda\envs\python_course\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\user\.conda\envs\python_course\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (6.0.2)
# Requirement already satisfied: rfc3339-validator in c:\users\user\.conda\envs\python_course\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\user\.conda\envs\python_course\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (0.1.1)
# Requirement already satisfied: wcwidth in c:\users\user\.conda\envs\python_course\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\.conda\envs\python_course\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\.conda\envs\python_course\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook) (2.2.2)
# Requirement already satisfied: executing>=1.2.0 in c:\users\user\.conda\envs\python_course\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\user\.conda\envs\python_course\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.4.1)
# Requirement already satisfied: pure-eval in c:\users\user\.conda\envs\python_course\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.3)
# Requirement already satisfied: fqdn in c:\users\user\.conda\envs\python_course\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\user\.conda\envs\python_course\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\user\.conda\envs\python_course\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (3.0.0)
# Requirement already satisfied: uri-template in c:\users\user\.conda\envs\python_course\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in c:\users\user\.conda\envs\python_course\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (24.8.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\user\.conda\envs\python_course\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\user\.conda\envs\python_course\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook) (2.22)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\user\.conda\envs\python_course\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in c:\users\user\.conda\envs\python_course\lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (2.9.0.20241003)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

df_ce = df[df['job_title_short'] == 'Cloud Engineer'].copy()
df_ce['job_posted_month'] = df_ce['job_posted_date'].dt.to_period('M')
monthly_job_postings = df_ce.groupby('job_posted_month').size()

monthly_job_postings.plot(
 kind='line', 
 linestyle=':', 
 color='purple', 
 marker='o'
 )
plt.title('Job Postings Trend for Cloud Engineers')
plt.ylabel('Count of Job Postings')
plt.xlabel('')
plt.show()

# %%
# Filter for Senior Data Analyst roles
SDA_df = df[df['job_title_short'] == 'Senior Data Analyst'].copy()

# Get the top 5 companies by number of postings
location_counts = SDA_df['company_name'].value_counts().head(5)

# Custom colors
colors = ['blue', 'orange', 'green', 'red', 'purple']

# Plot the bar chart
plt.bar(location_counts.index, location_counts.values, color=colors)
plt.xlabel('')
plt.ylabel('Number of Job Postings')
plt.title('Top 5 Companies hiring Senior Data Analysts by Number of Postings', fontsize=14)
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--')
plt.show()
