# %%
import pandas as pd
from datasets import load_dataset

dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# %%
df_copy = df.copy()
df_cleaned = df_copy.dropna(subset=['salary_year_avg'])
df_cleaned.head(5)
# Out:
#     job_title_short                                job_title  \
# 28   Data Scientist                      CRM Data Specialist
# 77    Data Engineer                            Data Engineer
# 92    Data Engineer  Remote - Data Engineer - Permanent - W2
# 100  Data Scientist  Data Scientist, Risk Data Mining - USDS
# 109    Data Analyst    Senior Supply Chain Analytics Analyst
#
#                                 job_location          job_via  \
# 28   San José Province, San José, Costa Rica  via Ai-Jobs.net
# 77                             Arlington, VA     via LinkedIn
# 92                                  Anywhere     via LinkedIn
# 100                        Mountain View, CA     via LinkedIn
# 109                                 Anywhere       via Get.It
#
#     job_schedule_type  job_work_from_home            search_location  \
# 28          Full-time               False                 Costa Rica
# 77          Full-time               False                      Sudan
# 92          Full-time                True    Illinois, United States
# 100         Full-time               False  California, United States
# 109         Full-time                True    Illinois, United States
#
#          job_posted_date  job_no_degree_mention  job_health_insurance  \
# 28   2023-08-01 13:37:57                  False                 False
# 77   2023-06-26 14:22:54                  False                 False
# 92   2023-02-21 13:29:59                  False                  True
# 100  2023-07-31 13:01:18                  False                  True
# 109  2023-10-12 13:02:19                  False                  True
#
#        job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 28      Costa Rica        year         109500.0              NaN
# 77           Sudan        year         140000.0              NaN
# 92   United States        year         120000.0              NaN
# 100  United States        year         228222.0              NaN
# 109  United States        year          89000.0              NaN
#
#                         company_name  \
# 28                          Netskope
# 77                        Intelletec
# 92                      Apex Systems
# 100                           TikTok
# 109  Get It Recruit - Transportation
#
#                                             job_skills  \
# 28                                   ['gdpr', 'excel']
# 77   ['mongodb', 'mongodb', 'python', 'r', 'sql', '...
# 92                                   ['sql', 'python']
# 100                  ['sql', 'r', 'python', 'express']
# 109              ['python', 'r', 'alteryx', 'tableau']
#
#                                        job_type_skills
# 28   {'analyst_tools': ['excel'], 'libraries': ['gd...
# 77   {'analyst_tools': ['tableau'], 'cloud': ['orac...
# 92                  {'programming': ['sql', 'python']}
# 100  {'programming': ['sql', 'r', 'python'], 'webfr...
# 109  {'analyst_tools': ['alteryx', 'tableau'], 'pro...

# %%
df_sampeled = df.sample(frac=0.1)
df_sampeled.head(5)
# Out:
#              job_title_short  \
# 324853          Data Analyst
# 115205          Data Analyst
# 512437         Data Engineer
# 544285      Business Analyst
# 447205  Senior Data Engineer
#
#                                                 job_title   job_location  \
# 324853  Data Quality Lead Analyst / SQL Developer/Inve...      Tampa, FL
# 115205                           Master Data Analyst Lead      Mauritius
# 512437                                      Data Engineer       Anywhere
# 544285                                   Business Analyst     Austin, TX
# 447205                               Senior Data Engineer  Milwaukee, WI
#
#              job_via job_schedule_type  job_work_from_home  \
# 324853      via Dice        Contractor               False
# 115205  via MyJob.mu         Full-time               False
# 512437  via LinkedIn         Full-time                True
# 544285    via Indeed         Full-time               False
# 447205  via LinkedIn         Full-time               False
#
#                 search_location      job_posted_date  job_no_degree_mention  \
# 324853   Florida, United States  2023-05-01 17:02:40                   True
# 115205                Mauritius  2023-02-21 09:32:32                  False
# 512437                    Italy  2023-11-02 11:18:30                  False
# 544285     Texas, United States  2023-09-21 19:01:08                  False
# 447205  Illinois, United States  2023-12-19 14:09:24                  False
#
#         job_health_insurance    job_country salary_rate  salary_year_avg  \
# 324853                 False  United States        None              NaN
# 115205                 False      Mauritius        None              NaN
# 512437                 False          Italy        None              NaN
# 544285                 False  United States        None              NaN
# 447205                 False  United States        None              NaN
#
#         salary_hour_avg              company_name  \
# 324853              NaN  RMS Computer Corporation
# 115205              NaN   AVA Creation Foundation
# 512437              NaN           Avangarde Group
# 544285              NaN            Robert Walters
# 447205              NaN            Nesco Resource
#
#                                                job_skills  \
# 324853                                    ['sql', 'jira']
# 115205                                               None
# 512437  ['python', 'mongodb', 'mongodb', 'databricks',...
# 544285                        ['sql', 'excel', 'tableau']
# 447205            ['sql', 'python', 'snowflake', 'azure']
#
#                                           job_type_skills
# 324853        {'async': ['jira'], 'programming': ['sql']}
# 115205                                               None
# 512437  {'cloud': ['databricks', 'azure'], 'databases'...
# 544285  {'analyst_tools': ['excel', 'tableau'], 'progr...
# 447205  {'cloud': ['snowflake', 'azure'], 'programming...

# %%
df_copy = df.copy()
median_salary = df_copy['salary_year_avg'].median()
df_copy['salary_year_avg'] = df_copy['salary_year_avg'].fillna(median_salary)
df_copy.loc[:5, 'salary_year_avg']
# Out:
# 0    115000.0
# 1    115000.0
# 2    115000.0
# 3    115000.0
# 4    115000.0
# 5    115000.0
# Name: salary_year_avg, dtype: float64
