# %%
# Importing Libraries
import ast
import pandas as pd
import seaborn as sns
from datasets import load_dataset
import matplotlib.pyplot as plt  

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df['job_skills'] = df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)

# %%
from matplotlib.ticker import FuncFormatter

# Create subplots for USA and Germany
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# USA Plot (Orange with reversed colors)
sns.boxplot(
    data=df_US_top6,
    x='salary_year_avg',
    y='job_title_short',
    order=job_order_US,
    ax=axes[0],
    palette=sns.color_palette("Oranges_r", len(job_order_US))  # Reverse the orange palette
)
axes[0].set_title('Salary Distributions of Top 6 Data Jobs in the USA (2023)', fontsize=14)
axes[0].set_xlabel('Yearly Salary (USD)')
axes[0].set_ylabel('')
axes[0].set_xlim(0, 600000)
axes[0].xaxis.set_major_formatter(FuncFormatter(lambda x, _: f'${int(x/1000)}K'))

# Germany Plot (Blue with reversed colors)
sns.boxplot(
    data=df_DE_top6,
    x='salary_year_avg',
    y='job_title_short',
    order=job_order_DE,
    ax=axes[1],
    palette=sns.color_palette("Blues_r", len(job_order_DE))  # Reverse the blue palette
)
axes[1].set_title('Salary Distributions of Top 6 Data Jobs in Germany (2023)', fontsize=14)
axes[1].set_xlabel('Yearly Salary (EUR)')
axes[1].set_ylabel('')
axes[1].set_xlim(0, 200000)
axes[1].xaxis.set_major_formatter(FuncFormatter(lambda x, _: f'€{int(x/1000)}K'))

# Adjust layout and display
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 8
#       4 fig, axes = plt.subplots(1, 2, figsize=(16, 6))
#       6 # USA Plot (Orange with reversed colors)
#       7 sns.boxplot(
# ----> 8     data=df_US_top6,
#       9     x='salary_year_avg',
#      10     y='job_title_short',
#      11     order=job_order_US,
#      12     ax=axes[0],
#      13     palette=sns.color_palette("Oranges_r", len(job_order_US))  # Reverse the orange palette
#      14 )
#      15 axes[0].set_title('Salary Distributions of Top 6 Data Jobs in the USA (2023)', fontsize=14)
#      16 axes[0].set_xlabel('Yearly Salary (USD)')
#
# NameError: name 'df_US_top6' is not defined

# %%
# Create Subplots: Left = USA, Right = Germany
fig, axes = plt.subplots(2, 2, figsize=(16, 10))

# USA: Highest Paid Skills (Left-Top)
sns.barplot(
    data=df_DA_top_pay_US,
    x='median',
    y=df_DA_top_pay_US.index,
    palette='Oranges_r',
    ax=axes[0, 0]
)
axes[0, 0].set_title('Highest Paid Skills (USA)')
axes[0, 0].set_xlabel('Median Salary (USD)')
axes[0, 0].set_ylabel('')
axes[0, 0].set_xlim(0, 200000)  # Set limit for x-axis
axes[0, 0].xaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f'${int(x/1000)}K'))

# Germany: Highest Paid Skills (Right-Top)
sns.barplot(
    data=df_DA_top_pay_DE,
    x='median',
    y=df_DA_top_pay_DE.index,
    palette='Blues_r',
    ax=axes[0, 1]
)
axes[0, 1].set_title('Highest Paid Skills (Germany)')
axes[0, 1].set_xlabel('Median Salary (EUR)')
axes[0, 1].set_ylabel('')
axes[0, 1].set_xlim(0, 200000)  # Set limit for x-axis
axes[0, 1].xaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f'€{int(x/1000)}K'))

# USA: Most In-Demand Skills (Left-Bottom)
sns.barplot(
    data=df_DA_skills_US,
    x='median',
    y=df_DA_skills_US.index,
    palette='Oranges_r',
    ax=axes[1, 0]
)
axes[1, 0].set_title('Most In-Demand Skills (USA)')
axes[1, 0].set_xlabel('Median Salary (USD)')
axes[1, 0].set_ylabel('')
axes[1, 0].set_xlim(0, 200000)  # Set limit for x-axis
axes[1, 0].xaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f'${int(x/1000)}K'))

# Germany: Most In-Demand Skills (Right-Bottom)
sns.barplot(
    data=df_DA_skills_DE,
    x='median',
    y=df_DA_skills_DE.index,
    palette='Blues_r',
    ax=axes[1, 1]
)
axes[1, 1].set_title('Most In-Demand Skills (Germany)')
axes[1, 1].set_xlabel('Median Salary (EUR)')
axes[1, 1].set_ylabel('')
axes[1, 1].set_xlim(0, 200000)  # Set limit for x-axis
axes[1, 1].xaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f'€{int(x/1000)}K'))

# Adjust Layout
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 6
#       2 fig, axes = plt.subplots(2, 2, figsize=(16, 10))
#       4 # USA: Highest Paid Skills (Left-Top)
#       5 sns.barplot(
# ----> 6     data=df_DA_top_pay_US,
#       7     x='median',
#       8     y=df_DA_top_pay_US.index,
#       9     palette='Oranges_r',
#      10     ax=axes[0, 0]
#      11 )
#      12 axes[0, 0].set_title('Highest Paid Skills (USA)')
#      13 axes[0, 0].set_xlabel('Median Salary (USD)')
#
# NameError: name 'df_DA_top_pay_US' is not defined
